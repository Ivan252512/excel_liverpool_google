# %%
import pandas as pd

# %%
doc = pd.read_excel('CUENTAS_FUN_SOCIEDADES.xlsx', None)

# %%
DF = doc['CUENTAS']

# %%
DF.loc[DF['Nivel 3'] == DF['Nivel 3'][0]]
# Out:
#       Cuenta                                Nivel 2  \
# 0   40000000  UTILBRUTA       **  UTILIDAD BRUTA **
# 1   40000001  UTILBRUTA       **  UTILIDAD BRUTA **
# 2   40000002  UTILBRUTA       **  UTILIDAD BRUTA **
# 3   40000003  UTILBRUTA       **  UTILIDAD BRUTA **
# 4   40000004  UTILBRUTA       **  UTILIDAD BRUTA **
# ..       ...                                    ...
# 56  40400001  UTILBRUTA       **  UTILIDAD BRUTA **
# 57  40400002  UTILBRUTA       **  UTILIDAD BRUTA **
# 58  40400003  UTILBRUTA       **  UTILIDAD BRUTA **
# 59  40400004  UTILBRUTA       **  UTILIDAD BRUTA **
# 61  40400006  UTILBRUTA       **  UTILIDAD BRUTA **
#
#                                   Nivel 3                            Nivel 4  \
# 0      VENTAS          TOTAL VENTAS NETAS     VTASCONTAD      VENTAS CONTADO
# 1      VENTAS          TOTAL VENTAS NETAS     VTASCONTAD      VENTAS CONTADO
# 2      VENTAS          TOTAL VENTAS NETAS     VTASCONTAD      VENTAS CONTADO
# ...

# %%
doc['Nivel 3'][0]

# %%
doc['CUENTAS']

# %%
type( pd.read_excel('CUENTAS_FUN_SOCIEDADES.xlsx', None)  )

# %%
"4000"==str(4000)

# %%
{"A":"a"}.keys()
# Out:
# dict_keys(['A'])

# %%
for i in doc.keys():
    print(i)
# Out:
# CUENTAS
# Sheet1
# FUN
# Sociedades
# JERQ_Cuentas

# %%
doc = pd.read_excel('CUENTAS_FUN_SOCIEDADES.xlsx', None)

# %%
type(doc['CUENTAS'])
# Out:
# pandas.core.frame.DataFrame
